# %%
import cv2
import os
import time

# Path to the input video and output directory for images
video_path = r'C:\Users\harshika.pathak\Desktop\WORK\object_detection\MicrosoftTeams-video.mp4'  # Replace with your video file path
output_image_dir = 'extracted_frames'  # Directory to save extracted frames

# Create output directory if it doesn't exist
if not os.path.exists(output_image_dir):
    os.makedirs(output_image_dir)

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if the video was opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Variables for FPS calculation
prev_frame_time = 0
frame_counter = 0

# Get the video's FPS (frames per second)
fps = cap.get(cv2.CAP_PROP_FPS)

# Loop through all frames in the video
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break  # If no more frames, exit the loop

    # Calculate FPS for the current frame
    new_frame_time = time.time()
    fps_value = 1 / (new_frame_time - prev_frame_time)  # Calculate FPS
    prev_frame_time = new_frame_time

    # Display FPS on the frame
    fps_text = f"FPS: {int(fps_value)}"
    cv2.putText(frame, fps_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)

    # Save the frame as an image
    frame_filename = os.path.join(output_image_dir, f"frame_{frame_counter:04d}.jpg")
    cv2.imwrite(frame_filename, frame)

    frame_counter += 1

# Release the video capture object
cap.release()

# Now, let's reassemble the images into a video
# Get the width and height of the frames (from the first frame)
frame_sample = cv2.imread(os.path.join(output_image_dir, "frame_0000.jpg"))
height, width, _ = frame_sample.shape

# %%
import cv2
import time
 
if __name__ == '__main__' :
 
    # Start default camera
    video = cv2.VideoCapture('C:\Users\harshika.pathak\Desktop\WORK\object_detection\MicrosoftTeams-video.mp4');
 
    # Find OpenCV version
    (major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')
 
    # With webcam get(CV_CAP_PROP_FPS) does not work.
    # Let's see for ourselves.
 
    if int(major_ver)  < 3 :
        fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
        print("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(fps))
    else :
        fps = video.get(cv2.CAP_PROP_FPS)
        print("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))
 
    # Number of frames to capture
    num_frames = 120;
 
    print("Capturing {0} frames".format(num_frames))
 
    # Start time
    start = time.time()
 
    # Grab a few frames
    for i in range(0, num_frames) :
        ret, frame = video.read()
 
    # End time
    end = time.time()
 
    # Time elapsed
    seconds = end - start
    print ("Time taken : {0} seconds".format(seconds))
 
    # Calculate frames per second
    fps  = num_frames / seconds
    print("Estimated frames per second : {0}".format(fps))
 
    # Release video
    video.release()
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 29.60339599757429
# Capturing 120 frames
# Time taken : 0.6351847648620605 seconds
# Estimated frames per second : 188.9214078144014

# %%
import cv2
import time  # Import the time module for adding sleep

# Open the video file
video = cv2.VideoCapture(r'C:\Users\harshika.pathak\Desktop\WORK\object_detection\MicrosoftTeams-video.mp4')
video_frame=[]
frame_width = int(video.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(video.get(cv2.CAP_PROP_FRAME_HEIGHT))
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output.mp4', fourcc, 20.0, (frame_width, frame_height))
while video.isOpened():
    ret, frame = video.read()
        
    if not ret:
        break  # Exit the loop if no frame is read (end of video)
    video_frame.append(frame)
    # Sleep for 5 seconds before writing the image
    # time.sleep(1)  
      # Save the frame as an image

# Release video object
video.release()
x= 20
for i in range(0,len(video_frame),int(len(video_frame)/x)):
 #print(i)
 val =video_frame[i]
 out.write(val)
 
 
 cv2.imwrite(f"output_frame/output_{i}.jpg", val)
out.release()

# %%
len(video_frame)
# Out:
# 678

# %%
import matplotlib.pyplot as plt

# %%
while cap.isOpened():
    ret, frame = cap.read()

# %%
ret,frame=video.read()
plt.imshow(frame)

# %%
frame_list=[]

# %% [markdown]
# # code fo reading images from  webcam

# %%
import cv2

# Open the default camera
cam = cv2.VideoCapture(0)

# Get the default frame width and height
frame_width = int(cam.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cam.get(cv2.CAP_PROP_FRAME_HEIGHT))

# # Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter('output.mp4', fourcc, 20.0, (frame_width, frame_height))

while True:
    ret, frame = cam.read()

    # Write the frame to the output file
    out.write(frame)

    # Display the captured frame
    cv2.imshow('Camera', frame)

    # Press 'q' to exit the loop
    if cv2.waitKey(1) == ord('q'):
        break

# Release the capture and writer objects
cam.release()
out.release()
cv2.destroyAllWindows()

# %%
# Out:
# 1280

# %%
frame_list
# Out:
# [array([[[223, 215, 215],
#          [223, 215, 215],
#          [223, 215, 215],
#          ...,
#          [ 42,  27,  28],
#          [ 42,  27,  28],
#          [ 42,  27,  28]],
#
#         [[223, 215, 215],
#          [223, 215, 215],
#          [223, 215, 215],
#          ...,
#          [ 41,  26,  27],
#          [ 41,  26,  27],
#          [ 41,  26,  27]],
#
#         [[223, 215, 215],
#          [223, 215, 215],
#          [223, 215, 215],
#          ...,
#          [ 41,  26,  27],
#          [ 41,  26,  27],
#          [ 41,  26,  27]],
#
#         ...,
#
#         [[ 19,  29, 128],
#          [ 19,  29, 128],
#          [ 19,  29, 128],
#          ...,
#          [ 74,  74,  88],
#          [ 75,  76,  86],
#          [ 76,  77,  87]],
#
#         [[ 19,  29, 128],
#          [ 19,  29, 128],
#          [ 19,  29, 128],
#          ...,
#          [ 68,  68,  82],
#          [ 69,  70,  80],
#          [ 70,  71,  81]],
#
#         [[ 19,  29, 128],
# ...
